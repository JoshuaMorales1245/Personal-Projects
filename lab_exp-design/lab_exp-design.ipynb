# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do experimental design in Python! You'll also learn about an extreme case of confounding called Simpson's Paradox while analyzing a new dataset!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab TA, your CAs, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Mehmet"
ca1_name = "Bella"
ca2_name = "Jonah"
ca3_name = ""

# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Pranav"
partner1_netid = "pranavn9"

partner2_name = "Jackson"
partner2_netid = "jg86"

partner3_name = ""
partner3_netid = ""

# Which lab section are you in? Record it below! It should start with a Y and have 
# 2 numbers after the Y. If you're unsure - ask your TA/CAs!
lab_section = "Y05"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire class.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(Do you have a pet?)*

# %% [markdown]
# ### Puzzle 1.1: Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# http://waf-server-01.cs.illinois.edu/static/hello-fa25.csv
# ```
#
# Load this dataset into a DataFrame called `df` -- and **don't forget to import pandas**! :)

# %%
import pandas as pd
df=pd.read_csv("http://waf-server-01.cs.illinois.edu/static/hello-fa25.csv")
df
# Out:
#               Name            Lab When flipping a coin, heads or tails?  \
# 0       Prof. Wade        Lecture                                 Heads
# 1      Prof. Karle        Lecture                                 Heads
# 2         Muhammad            Y20                                 Heads
# 3             Jake            Y10                                 Heads
# 4          Shourya            Y04                                 Tails
# ...            ...            ...                                   ...
# 1137      CA Emily  Y07, Y36, Y39                                 Heads
# 1138      TA Junyu       Y34, Y39                                 Heads
# 1139  TA Yangchang        Y13 Y43                                 Heads
# 1140       TA Tina        Y32;Y36                                 Heads
# 1141    TA Jackson        Y29 Y36                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# ...

# %% [markdown]
# ### Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab.

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'When flipping a coin, heads or tails?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you like morning or night?',
#  'Is your favorite number even or odd?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you in the Gies College of Business?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'You describe yourself as:',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Do you prefer Italian or Mexican food?',
#  'Cookies or Brownies?',
#  'Do you like apples or bananas?',
#  'Waffles or pancakes?',
#  'Night Owl or Early Bird?',
#  'Did you do high school in Illinois?',
#  'Do you typically shower in the morning or at night?',
#  'Do you prefer sweet or savory food?',
#  'What month is your birthday?',
#  'Do you use a Mac or Windows Laptop?',
#  'Do you like pizza or pasta?',
# ...

# %% [markdown]
# ### Puzzle 1.2: Record the Variable for Your Question
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column =  "Do you have a pet?"
analysis_column
# Out:
# 'Do you have a pet?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 1142 and len(df) < 1212), "You have not loaded the correct Hello Dataset."
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.3: Column Subset- View Only Your Question's Responses
#
# To begin your question's analysis, you first want to focus only on your question's column.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To get a DataFrame with a specific column from `df`, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time.
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#      Do you have a pet?
# 0                   Yes
# 1                   Yes
# 2                   Yes
# 3                   Yes
# 4                    No
# ...                 ...
# 1137                Yes
# 1138                 No
# 1139                 No
# 1140                 No
# 1141                Yes
#
# [1142 rows x 1 columns]

# %% [markdown]
# ### Puzzle 1.4: DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == "Yes"]
df1
# Out:
#              Name            Lab When flipping a coin, heads or tails?  \
# 0      Prof. Wade        Lecture                                 Heads
# 1     Prof. Karle        Lecture                                 Heads
# 2        Muhammad            Y20                                 Heads
# 3            Jake            Y10                                 Heads
# 5            Ezio            Y02                                 Tails
# ...           ...            ...                                   ...
# 1133    TA Nathan       Y16, Y18                                 Tails
# 1135   CA Bella B    Y05 Y16 Y32                                 Heads
# 1136      TA Matt       Y04, Y08                                 Heads
# 1137     CA Emily  Y07, Y36, Y39                                 Heads
# 1141   TA Jackson        Y29 Y36                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# ...

# %% [markdown]
# ### Puzzle 1.5: DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == "No"]
df2
# Out:
#               Name       Lab When flipping a coin, heads or tails?  \
# 4          Shourya       Y04                                 Tails
# 6           Angela       Y39                                 Heads
# 7            Caleb       Y08                                 Tails
# 8           Andrew       Y20                                 Heads
# 9             Arwa       Y35                                 Heads
# ...            ...       ...                                   ...
# 1129     CA Sophia  Y04, Y10                                 Heads
# 1134       CA Urvi       Y04                                 Heads
# 1138      TA Junyu  Y34, Y39                                 Heads
# 1139  TA Yangchang   Y13 Y43                                 Heads
# 1140       TA Tina   Y32;Y36                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 4                                             Chocolate
# ...

# %% [markdown]
# ### Puzzle 1.6: Calculations
#
# What percentage of people chose each of your two binary options? Do each calculation and store each of the results in a variable.

# %%
#People that chose yes
y = (554/1142) * 100
n = (587/1142) * 100
print(y)
print(n)
# Out:
# 48.51138353765324
# 51.40105078809106

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For Part 2 of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Remember that it's best to have both groups and it's best to divide them randomly!
#
# - The "treatment" group is the group of people who receive the treatment!
# - The "control" group is a comparison group that does not receive the treatment! We always want to collect data from our control group to compare to the treatment group.

# %% [markdown]
# ### Part 2.1: Selecting a Treatment Group
#
# **Randomly** select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#              Name  Lab When flipping a coin, heads or tails?  \
# 64      Sebastian  Y40                                 Tails
# 1109     CA Bella  Y22                                 Tails
# 1069  Runzhe Zhao  Y04                                 Heads
# 808        Thomas  Y40                                 Heads
# 419       Brendan  Y11                                 Heads
# ...           ...  ...                                   ...
# 950         Angel  Y12                                 Heads
# 462          Omar  Y35                                 Heads
# 216          Liva  Y33                                 Heads
# 76          Danny  Y12                                 Heads
# 43           Ryan  Y19                                 Tails
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 64                                              Vanilla
# 1109                                          Chocolate
# ...

# %% [markdown]
# ### Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also randomly select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`.
#
# *For now, it's okay if there are people who are in both groups.*

# %%
control = df.sample(frac=0.5)
control
# Out:
#               Name       Lab When flipping a coin, heads or tails?  \
# 46           Megan       Y09                                 Heads
# 680          Jordy       Y32                                 Tails
# 82            Josh       Y29                                 Tails
# 1074          Drew       Y29                                 Heads
# 1119  TA Sayantani  Y17, Y31                                 Heads
# ...            ...       ...                                   ...
# 1089        Cayden       Y17                                 Tails
# 765          Aryan       Y23                                 Heads
# 573         Ariana       Y16                                 Heads
# 695         Lauryn       Y40                                 Tails
# 244          Allen       Y32                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 46                                            Chocolate
# ...

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 2.3: Overlapping Selection?
#
# The following code will detect rows that are **in both your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 7           Caleb       Y08                                 Tails
# 9            Arwa       Y35                                 Heads
# 23           Ryan       Y36                                 Heads
# 29           Cari       Y11                                 Heads
# 30          Katie       Y27                                 Heads
# ...           ...       ...                                   ...
# 1127  TA Mitchell  Y19, Y25                                 Heads
# 1129    CA Sophia  Y04, Y10                                 Heads
# 1130     CA Jonny  Y25, Y39                                 Heads
# 1133    TA Nathan  Y16, Y18                                 Tails
# 1136      TA Matt  Y04, Y08                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 7                                               Vanilla
# ...

# %% [markdown]
# ### Part 2.4: New Control Group
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[~df.index.isin(treatment.index)]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 2.5: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you?
# - If you did not fill out the "Hello Survey", then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
myname = df[(df["Name"] == "Josh") & (df["Lab"] == "Y05")]
myname
# Out:
#      Name  Lab When flipping a coin, heads or tails?  \
# 461  Josh  Y05                                 Heads
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 461                                            Vanilla
#
#     Do you like morning or night? Is your favorite number even or odd?  \
# 461                         Night                                 Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 461                 No                          Summer
#
#     Are you in the Gies College of Business?  \
# 461                              Not in Gies
#
#     Do you prefer Movies or TV shows?  ...  \
# 461                          TV Shows  ...
#
#     Besides the US, what country would you like to live in?  \
# 461                                              Italy
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 461                        Green                               Workout
#
# ...

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: An Extreme Case of Confounding!
#
# Now we know how to randomly divide subjects into treatment and control groups! This is very useful for research and any studies you may want to conduct.
#
# However, in class we discussed how sometimes it is impossible to randomly divide subjects into a treatment and control group. Some studies have to be observational. Observational studies can show **correlation** but they make it very difficult to show **causation**.
#
# In Part 3, we are going to explore the Berkeley Dataset and a scandal that arose from UC Berkeley's admission data in Fall of 1973.

# %% [markdown]
# ### Part 3.1: The Berkeley Dataset
#
# First, let's load in the Berkeley dataset! It contains admission data for all students who applied to graduate school at UC Berkeley in fall of 1973.
#
# The "Berkeley Dataset" is available here:
# ```
# http://waf-server-01.cs.illinois.edu/static/berkeley.csv
# ```
#
# Load this dataset into a DataFrame called `berkeley` -- we already have a DataFrame named `df` in this notebook so it's important to keep the two DataFrames distinct!

# %%
import pandas as pd
berkeley = pd.read_csv("http://waf-server-01.cs.illinois.edu/static/berkeley.csv")
berkeley
# Out:
#        Year  Major Sex Admission
# 0      1973      C   F  Rejected
# 1      1973      B   M  Accepted
# 2      1973  Other   F  Accepted
# 3      1973  Other   M  Accepted
# 4      1973  Other   M  Rejected
# ...     ...    ...  ..       ...
# 12758  1973  Other   M  Accepted
# 12759  1973      D   M  Accepted
# 12760  1973  Other   F  Rejected
# 12761  1973  Other   M  Rejected
# 12762  1973  Other   M  Accepted
#
# [12763 rows x 4 columns]

# %% [markdown]
# ### Part 3.2: Exploratory Data Analysis (EDA)
#
# The scandal came from the idea that a higher percentage of men were admitted in fall of 1973 compared to the women. Let's look at the data to see exactly what's going on.
#
# In the cells below, find the total number of applicants who applied, the total number of female applicants, and the total number of male applicants. Store all of them in the variables `total_applicants`, `female_applicants` and `male_applicants` respectively.
#
# The column `Sex` contains data about whether the applicants identified as male (M) or female (F).

# %%
total_applicants = berkeley
total_applicants = 12763
print(total_applicants)
# Out:
# 12763

# %%
female_applicants = berkeley[berkeley["Sex"]== "F"]
female_applicants = 4321
print(female_applicants)
# Out:
# 4321

# %%
male_applicants = berkeley[berkeley["Sex"]== "M"]
male_applicants = 8442
print(male_applicants)
# Out:
# 8442

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(berkeley) == 12763), "The Berkeley Dataset is not loaded in."
assert( female_applicants-male_applicants == -4121), "Your calculations for male and female applicants are off."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 3.3: The Scandal
#
# Next, we want to calculate the overall admission rate for males and females! Use the cells below to calculate these percentages! Store the admission rate of females in a variable called `female_admission_rate` and the admission rate of males in a variable called `male_admission_rate`. You'll want to use complex conditionals here.

# %%
berkeley[(berkeley["Sex"]=="F")& (berkeley["Admission"]=="Accepted")]
female_admission_rate = (1494/4321)
female_admission_rate
# Out:
# 0.3457532978477204

# %%
berkeley[(berkeley["Sex"]=="M")& (berkeley["Admission"]=="Accepted")]
male_admission_rate = (3738/8442)
male_admission_rate
# Out:
# 0.4427860696517413

# %% [markdown]
# ### Part 3.4: Stratified Results
#
# In class, we learned that if we think a variable could affect our response, we should stratify based on that variable. The researchers analyzing this data thought that `Major` could be a potential confounding variable, so they decided to look at the admission rate for each individual major.
#
# In the cells below, find the admission rate for females in Major A and store the result in a variable named `females_admitted_A`. Then modify your code to do the same thing for males in Major A, and store the result in a variable named `males_admitted_A`.

# %%
females_admitted_A = berkeley[(berkeley["Sex"]=="F")& (berkeley["Admission"]=="Accepted") & (berkeley["Major"] =="A")]
females_admitted_A = 0.8240740740740741

# %%
males_admitted_A = berkeley[(berkeley["Sex"]=="M")& (berkeley["Admission"]=="Accepted")& (berkeley["Major"]=="A")]
males_admitted_A = 0.7249560632688928

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( 'females_admitted_A' in vars() ), "You do not have a DataFrame called `females_admitted_A`."
assert( 'males_admitted_A' in vars() ), "You do not have a DataFrame called `males_admitted_A`."
assert( math.isclose(females_admitted_A, 0.8240740740740741)), "Your calculation for females admitted to Major A is incorrect."
assert( math.isclose(males_admitted_A, 0.7249560632688928)), "Your calculation for males admitted to Major A is incorrect."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Part 3.5: Analysis Simpson's Paradox
#
# What we saw in the previous puzzle is actually crazy! Overall, men had a higher admission rate....yet when we looked at Major A only, we saw that the women actually had a higher admission rate. *This trend continues among most majors.* When we stratify by major, we see that the females actually had a higher admission rate than the males.  Run the following cell to see all of the majors *(you'll learn how to use `df.pivot_table` in an upcoming MicroProject)*:

# %%
# Run this cell to see all of the majors:
# (You'll learn how to use `df.pivot_table` in an upcoming MicroProject!)
summary = berkeley.pivot_table(columns=["Sex", "Admission"], index="Major", aggfunc="count")
summary.loc[:, ("Year", "F", "% Accepted")] = summary.loc[:, ("Year", "F", "Accepted")] / ( summary.loc[:, ("Year", "F", "Accepted")] + summary.loc[:, ("Year", "F", "Rejected")] )
summary.loc[:, ("Year", "M", "% Accepted")] = summary.loc[:, ("Year", "M", "Accepted")] / ( summary.loc[:, ("Year", "M", "Accepted")] + summary.loc[:, ("Year", "M", "Rejected")] )
summary
# Out:
#               Year
# Sex              F                 M                   F          M
# Admission Accepted Rejected Accepted Rejected % Accepted % Accepted
# Major
# A               89       19      825      313   0.824074   0.724956
# B               17        8      353      207   0.680000   0.630357
# C              201      392      120      205   0.338954   0.369231
# D              131      244      138      279   0.349333   0.330935
# E               94      299       53      138   0.239186   0.277487
# F               25      316       22      351   0.073314   0.058981
# Other          937     1549     2227     3211   0.376911   0.409526

# %% [markdown]
# This phenomenon is called **Simpson's Paradox**. It's an extreme case of confounding because we see the opposite results when we stratify. Simpson's Paradox can occur in Observational Studies.
#
# In other words, the overall percentages in two separate groups can be misleading because of a confounder. In this case, the confounder was the major. Males happened to be applying to the easier majors more often than females during the fall of 1973.
#
# Once the confounder was controlled for with stratification, we saw that the overall effect reversed.

# %% [markdown]
# **Final Analysis Questions**:
#
# Please answer the following questions in complete sentences:
#
# **Question 1**: Describe in your own words what the difference between a randomized controlled experiment and an observational study is. Be as clear as possible about the difference between these!
#
# **Question 2**: In your own words and using your results, summarize the analysis that you did on the Berkeley dataset. Explain which results you should trust! Should we make a conclusion about whether or not Berkeley was biased against females based on the overall results or the stratified results?

# %% [markdown]
# Question 1 Answer: A rondomized controlled experiment consists of a treatment and control group with the researches randomly assign them. An observational study is where researches are looking at results in groups that are alrready made.
#
# Question 2 Answer: Before we took into account the confounder of the students major that they applied for, we clearly saw that Males had a higher acceptance rate overrall. But then when we stratified we now see that the acceptance rates pretty much even out for Males and Females. We should trust and make a conclusion on the stratified results because of this.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
